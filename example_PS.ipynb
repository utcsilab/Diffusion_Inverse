# %%
import numpy as np
import glob
import torch
from tqdm import tqdm
# import sigpy as sp
import matplotlib.pyplot as plt
import os
import argparse
from utils import nrmse, ifft, fft
from sampling_funcs import StackedRandomGenerator, simple_ODE_ps, general_SDE_ps
import pickle
import dnnlib
from torch_utils import distributed as dist
from skimage.metrics import structural_similarity as ssim
import random
os.environ["CUDA_DEVICE_ORDER"]= "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]='0'

# %%
# set random seeds
seed = 0
torch.manual_seed(seed)
np.random.seed(seed)
device=torch.device('cuda')

# %% [markdown]
# ## Load Data and Generate Subsampled kspace

# %%
# load data (NOTE: this is single coil data artificially generated from Multicoil data with thresholded sensitivity maps)
data_file = 'test_data.pt'
cont = torch.load(data_file)
gt_img = cont['gt_img'].to(device)
ksp_fs = cont['ksp'].to(device)
maps = torch.ones_like(ksp_fs)

# %%
# undersample kspace
def sampling_mask_gen(ACS_perc, R, img_sz):
    ACS = int(ACS_perc*img_sz)
    outer_line_count = int(int(img_sz/R) - ACS)
    mask = np.zeros((img_sz,img_sz))
    # use 14 lines for center of ksp
    ACS_start = int(img_sz/2)-int(ACS/2)
    ACS_end = ACS_start + ACS
    center_idx = np.arange(ACS_start,ACS_end) # ACS_perc*img_sz central lines for ACS
    total_idx = np.arange(img_sz)
    rem_lines = np.delete(total_idx, center_idx)

    random.shuffle(rem_lines)
    mask_lines=np.concatenate((center_idx,rem_lines[0:outer_line_count]))


    # print(mask_lines)
    mask[:,mask_lines] = 1

    mask_batched = mask[None,None]

    return mask_batched

# %%
# generate sampling mask
ACS_perc = 0.08
R = 3
img_sz = ksp_fs.shape[-1]
mask = torch.tensor(sampling_mask_gen(ACS_perc, R, img_sz))
mask = mask.to(device)
ksp_us = ksp_fs*mask

us_recon = ifft(ksp_us)
norm_const = torch.max(abs(us_recon))
# norm_const = torch.max(abs(gt_img))

y_meas = ksp_us/norm_const
norm_gt_img = gt_img/norm_const


plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.title('GT')
plt.imshow(np.flipud(abs(gt_img[0,0]).cpu()),cmap = 'gray')
plt.axis('off')
plt.subplot(1,3,2)
plt.title('Sampled ksp')
plt.imshow(np.flipud(abs(ksp_us[0,0]**.2).cpu()),cmap = 'gray')
plt.axis('off')
plt.subplot(1,3,3)
plt.title('Subsampled Image')
plt.imshow(np.flipud(abs(us_recon[0,0]).cpu()),cmap = 'gray')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %% [markdown]
# ## Set Inference Parameters

# %%
l_ss           = 1 # liklihood step size
sigma_max      = 10 # largest noise level to start at
num_steps      = 300 # number of inference steps to use
discretization = 'edm' # ['vp', 've', 'iddpm', 'edm'] type of time step disctretization to use when solving reverse SDE
solver         = 'euler' # ['euler', 'heun'] type of SDE solver to use (this should always be euler for now)
schedule       = 'vp' # ['vp', 've', 'linear'] this designates the type of noise level scaling schedule used
scaling        = 'vp' # ['vp', 'none'] this determines the type of scaling used on the underlying image

# %% [markdown]
# ## load network

# %%
# replace this with your saved network
net_save = '/csiNAS2/slow/brett/edm_outputs/00037-fastmri_brain_preprocessed_9_25_23-uncond-ddpmpp-edm-gpus4-batch40-fp32-aspect/network-snapshot-004800.pkl'

if dist.get_rank() != 0:
        torch.distributed.barrier()

# Load network.
dist.print0(f'Loading network from "{net_save}"...')
with dnnlib.util.open_url(net_save, verbose=(dist.get_rank() == 0)) as f:
    net = pickle.load(f)['ema'].to(device)
# Out:
# Loading network from "/csiNAS2/slow/brett/edm_outputs/00037-fastmri_brain_preprocessed_9_25_23-uncond-ddpmpp-edm-gpus4-batch40-fp32-aspect/network-snapshot-004800.pkl"...

# %%
# create initialization vector for diffusion process.
batch_size = 1
rnd = StackedRandomGenerator(device, [seed])
latents = rnd.randn([batch_size, net.img_channels, net.img_resolution, net.img_resolution], device=device)
class_labels = None

# %% [markdown]
# ## Do Posterior Sampling

# %%
image_recon = general_SDE_ps(y=y_meas, mask=mask, maps=torch.ones_like(y_meas), l_ss=l_ss, 
    net=net, latents=latents, class_labels=None, randn_like=torch.randn_like,
    num_steps=num_steps, sigma_min=0.002, sigma_max=sigma_max, rho=7,
    solver=solver, discretization=discretization, schedule='linear', scaling=scaling,
    epsilon_s=1e-3, C_1=0.001, C_2=0.008, M=1000, alpha=1,
    S_churn=0, S_min=0, S_max=float('inf'), S_noise=1, gt_img=norm_gt_img, verbose = True)
    
cplx_recon = torch.view_as_complex(image_recon.permute(0,-2,-1,1).contiguous())[None] #shape: [1,1,H,W]
cplx_recon = cplx_recon*norm_const
# Out:
# Step:0 ,  NRMSE: 4.649
# Step:1 ,  NRMSE: 4.518
# Step:2 ,  NRMSE: 4.400
# Step:3 ,  NRMSE: 4.294
# Step:4 ,  NRMSE: 4.202
# Step:5 ,  NRMSE: 4.124
# Step:6 ,  NRMSE: 4.058
# Step:7 ,  NRMSE: 4.006
# Step:8 ,  NRMSE: 3.968
# Step:9 ,  NRMSE: 3.942
# Step:10 ,  NRMSE: 3.929
# Step:11 ,  NRMSE: 3.927
# Step:12 ,  NRMSE: 3.926
# Step:13 ,  NRMSE: 3.924
# Step:14 ,  NRMSE: 3.923
# Step:15 ,  NRMSE: 3.920
# Step:16 ,  NRMSE: 3.921
# Step:17 ,  NRMSE: 3.916
# Step:18 ,  NRMSE: 3.918
# Step:19 ,  NRMSE: 3.911
# Step:20 ,  NRMSE: 3.916
# Step:21 ,  NRMSE: 3.905
# Step:22 ,  NRMSE: 3.914
# Step:23 ,  NRMSE: 3.898
# Step:24 ,  NRMSE: 3.912
# Step:25 ,  NRMSE: 3.892
# Step:26 ,  NRMSE: 3.908
# Step:27 ,  NRMSE: 3.887
# Step:28 ,  NRMSE: 3.901
# Step:29 ,  NRMSE: 3.885
# Step:30 ,  NRMSE: 3.895
# Step:31 ,  NRMSE: 3.884
# Step:32 ,  NRMSE: 3.888
# Step:33 ,  NRMSE: 3.885
# Step:34 ,  NRMSE: 3.882
# Step:35 ,  NRMSE: 3.885
# Step:36 ,  NRMSE: 3.876
# Step:37 ,  NRMSE: 3.881
# Step:38 ,  NRMSE: 3.870
# Step:39 ,  NRMSE: 3.874
# Step:40 ,  NRMSE: 3.864
# Step:41 ,  NRMSE: 3.867
# Step:42 ,  NRMSE: 3.858
# Step:43 ,  NRMSE: 3.859
# Step:44 ,  NRMSE: 3.851
# Step:45 ,  NRMSE: 3.851
# Step:46 ,  NRMSE: 3.842
# Step:47 ,  NRMSE: 3.842
# Step:48 ,  NRMSE: 3.832
# Step:49 ,  NRMSE: 3.834
# Step:50 ,  NRMSE: 3.822
# Step:51 ,  NRMSE: 3.825
# Step:52 ,  NRMSE: 3.813
# Step:53 ,  NRMSE: 3.815
# Step:54 ,  NRMSE: 3.805
# Step:55 ,  NRMSE: 3.804
# Step:56 ,  NRMSE: 3.795
# Step:57 ,  NRMSE: 3.793
# Step:58 ,  NRMSE: 3.785
# Step:59 ,  NRMSE: 3.781
# Step:60 ,  NRMSE: 3.773
# Step:61 ,  NRMSE: 3.767
# Step:62 ,  NRMSE: 3.760
# Step:63 ,  NRMSE: 3.754
# Step:64 ,  NRMSE: 3.747
# Step:65 ,  NRMSE: 3.739
# Step:66 ,  NRMSE: 3.731
# Step:67 ,  NRMSE: 3.722
# Step:68 ,  NRMSE: 3.716
# Step:69 ,  NRMSE: 3.706
# Step:70 ,  NRMSE: 3.698
# Step:71 ,  NRMSE: 3.688
# Step:72 ,  NRMSE: 3.676
# Step:73 ,  NRMSE: 3.672
# Step:74 ,  NRMSE: 3.657
# Step:75 ,  NRMSE: 3.652
# Step:76 ,  NRMSE: 3.635
# Step:77 ,  NRMSE: 3.629
# Step:78 ,  NRMSE: 3.612
# Step:79 ,  NRMSE: 3.604
# Step:80 ,  NRMSE: 3.588
# Step:81 ,  NRMSE: 3.577
# Step:82 ,  NRMSE: 3.562
# Step:83 ,  NRMSE: 3.549
# Step:84 ,  NRMSE: 3.534
# Step:85 ,  NRMSE: 3.520
# Step:86 ,  NRMSE: 3.504
# Step:87 ,  NRMSE: 3.489
# Step:88 ,  NRMSE: 3.472
# Step:89 ,  NRMSE: 3.456
# Step:90 ,  NRMSE: 3.438
# Step:91 ,  NRMSE: 3.421
# Step:92 ,  NRMSE: 3.402
# Step:93 ,  NRMSE: 3.384
# Step:94 ,  NRMSE: 3.364
# Step:95 ,  NRMSE: 3.345
# Step:96 ,  NRMSE: 3.323
# Step:97 ,  NRMSE: 3.303
# Step:98 ,  NRMSE: 3.280
# Step:99 ,  NRMSE: 3.259
# Step:100 ,  NRMSE: 3.235
# Step:101 ,  NRMSE: 3.213
# Step:102 ,  NRMSE: 3.187
# Step:103 ,  NRMSE: 3.164
# Step:104 ,  NRMSE: 3.137
# Step:105 ,  NRMSE: 3.112
# Step:106 ,  NRMSE: 3.084
# Step:107 ,  NRMSE: 3.058
# Step:108 ,  NRMSE: 3.029
# Step:109 ,  NRMSE: 3.002
# Step:110 ,  NRMSE: 2.971
# Step:111 ,  NRMSE: 2.943
# Step:112 ,  NRMSE: 2.911
# Step:113 ,  NRMSE: 2.882
# Step:114 ,  NRMSE: 2.849
# Step:115 ,  NRMSE: 2.819
# Step:116 ,  NRMSE: 2.785
# Step:117 ,  NRMSE: 2.753
# Step:118 ,  NRMSE: 2.718
# Step:119 ,  NRMSE: 2.685
# Step:120 ,  NRMSE: 2.650
# Step:121 ,  NRMSE: 2.616
# Step:122 ,  NRMSE: 2.579
# Step:123 ,  NRMSE: 2.544
# Step:124 ,  NRMSE: 2.507
# Step:125 ,  NRMSE: 2.472
# Step:126 ,  NRMSE: 2.434
# Step:127 ,  NRMSE: 2.398
# Step:128 ,  NRMSE: 2.360
# Step:129 ,  NRMSE: 2.323
# Step:130 ,  NRMSE: 2.284
# Step:131 ,  NRMSE: 2.247
# Step:132 ,  NRMSE: 2.209
# Step:133 ,  NRMSE: 2.171
# Step:134 ,  NRMSE: 2.132
# Step:135 ,  NRMSE: 2.094
# Step:136 ,  NRMSE: 2.056
# Step:137 ,  NRMSE: 2.018
# Step:138 ,  NRMSE: 1.979
# Step:139 ,  NRMSE: 1.941
# Step:140 ,  NRMSE: 1.903
# Step:141 ,  NRMSE: 1.865
# Step:142 ,  NRMSE: 1.827
# Step:143 ,  NRMSE: 1.789
# Step:144 ,  NRMSE: 1.751
# Step:145 ,  NRMSE: 1.713
# Step:146 ,  NRMSE: 1.676
# Step:147 ,  NRMSE: 1.639
# Step:148 ,  NRMSE: 1.602
# Step:149 ,  NRMSE: 1.566
# Step:150 ,  NRMSE: 1.529
# Step:151 ,  NRMSE: 1.493
# Step:152 ,  NRMSE: 1.458
# Step:153 ,  NRMSE: 1.422
# Step:154 ,  NRMSE: 1.387
# Step:155 ,  NRMSE: 1.353
# Step:156 ,  NRMSE: 1.319
# Step:157 ,  NRMSE: 1.285
# Step:158 ,  NRMSE: 1.252
# Step:159 ,  NRMSE: 1.219
# Step:160 ,  NRMSE: 1.187
# Step:161 ,  NRMSE: 1.155
# Step:162 ,  NRMSE: 1.123
# Step:163 ,  NRMSE: 1.092
# Step:164 ,  NRMSE: 1.062
# Step:165 ,  NRMSE: 1.032
# Step:166 ,  NRMSE: 1.002
# Step:167 ,  NRMSE: 0.973
# Step:168 ,  NRMSE: 0.944
# Step:169 ,  NRMSE: 0.916
# Step:170 ,  NRMSE: 0.889
# Step:171 ,  NRMSE: 0.861
# Step:172 ,  NRMSE: 0.835
# Step:173 ,  NRMSE: 0.808
# Step:174 ,  NRMSE: 0.782
# Step:175 ,  NRMSE: 0.757
# Step:176 ,  NRMSE: 0.732
# Step:177 ,  NRMSE: 0.707
# Step:178 ,  NRMSE: 0.683
# Step:179 ,  NRMSE: 0.660
# Step:180 ,  NRMSE: 0.636
# Step:181 ,  NRMSE: 0.613
# Step:182 ,  NRMSE: 0.591
# Step:183 ,  NRMSE: 0.569
# Step:184 ,  NRMSE: 0.547
# Step:185 ,  NRMSE: 0.526
# Step:186 ,  NRMSE: 0.504
# Step:187 ,  NRMSE: 0.484
# Step:188 ,  NRMSE: 0.464
# Step:189 ,  NRMSE: 0.444
# Step:190 ,  NRMSE: 0.425
# Step:191 ,  NRMSE: 0.406
# Step:192 ,  NRMSE: 0.388
# Step:193 ,  NRMSE: 0.371
# Step:194 ,  NRMSE: 0.354
# Step:195 ,  NRMSE: 0.338
# Step:196 ,  NRMSE: 0.324
# Step:197 ,  NRMSE: 0.308
# Step:198 ,  NRMSE: 0.298
# Step:199 ,  NRMSE: 0.285
# Step:200 ,  NRMSE: 0.274
# Step:201 ,  NRMSE: 0.260
# Step:202 ,  NRMSE: 0.253
# Step:203 ,  NRMSE: 0.240
# Step:204 ,  NRMSE: 0.233
# Step:205 ,  NRMSE: 0.223
# Step:206 ,  NRMSE: 0.218
# Step:207 ,  NRMSE: 0.210
# Step:208 ,  NRMSE: 0.206
# Step:209 ,  NRMSE: 0.200
# Step:210 ,  NRMSE: 0.197
# Step:211 ,  NRMSE: 0.193
# Step:212 ,  NRMSE: 0.191
# Step:213 ,  NRMSE: 0.187
# Step:214 ,  NRMSE: 0.185
# Step:215 ,  NRMSE: 0.182
# Step:216 ,  NRMSE: 0.180
# Step:217 ,  NRMSE: 0.177
# Step:218 ,  NRMSE: 0.175
# Step:219 ,  NRMSE: 0.173
# Step:220 ,  NRMSE: 0.170
# Step:221 ,  NRMSE: 0.168
# Step:222 ,  NRMSE: 0.165
# Step:223 ,  NRMSE: 0.163
# Step:224 ,  NRMSE: 0.160
# Step:225 ,  NRMSE: 0.158
# Step:226 ,  NRMSE: 0.155
# Step:227 ,  NRMSE: 0.153
# Step:228 ,  NRMSE: 0.150
# Step:229 ,  NRMSE: 0.147
# Step:230 ,  NRMSE: 0.145
# Step:231 ,  NRMSE: 0.142
# Step:232 ,  NRMSE: 0.139
# Step:233 ,  NRMSE: 0.136
# Step:234 ,  NRMSE: 0.134
# Step:235 ,  NRMSE: 0.131
# Step:236 ,  NRMSE: 0.129
# Step:237 ,  NRMSE: 0.126
# Step:238 ,  NRMSE: 0.123
# Step:239 ,  NRMSE: 0.120
# Step:240 ,  NRMSE: 0.118
# Step:241 ,  NRMSE: 0.115
# Step:242 ,  NRMSE: 0.113
# Step:243 ,  NRMSE: 0.111
# Step:244 ,  NRMSE: 0.109
# Step:245 ,  NRMSE: 0.106
# Step:246 ,  NRMSE: 0.105
# Step:247 ,  NRMSE: 0.103
# Step:248 ,  NRMSE: 0.101
# Step:249 ,  NRMSE: 0.099
# Step:250 ,  NRMSE: 0.098
# Step:251 ,  NRMSE: 0.096
# Step:252 ,  NRMSE: 0.095
# Step:253 ,  NRMSE: 0.093
# Step:254 ,  NRMSE: 0.092
# Step:255 ,  NRMSE: 0.090
# Step:256 ,  NRMSE: 0.089
# Step:257 ,  NRMSE: 0.088
# Step:258 ,  NRMSE: 0.086
# Step:259 ,  NRMSE: 0.085
# Step:260 ,  NRMSE: 0.084
# Step:261 ,  NRMSE: 0.083
# Step:262 ,  NRMSE: 0.082
# Step:263 ,  NRMSE: 0.081
# Step:264 ,  NRMSE: 0.080
# Step:265 ,  NRMSE: 0.079
# Step:266 ,  NRMSE: 0.079
# Step:267 ,  NRMSE: 0.079
# Step:268 ,  NRMSE: 0.079
# Step:269 ,  NRMSE: 0.079
# Step:270 ,  NRMSE: 0.079
# Step:271 ,  NRMSE: 0.079
# Step:272 ,  NRMSE: 0.080
# Step:273 ,  NRMSE: 0.079
# Step:274 ,  NRMSE: 0.080
# Step:275 ,  NRMSE: 0.079
# Step:276 ,  NRMSE: 0.080
# Step:277 ,  NRMSE: 0.079
# Step:278 ,  NRMSE: 0.080
# Step:279 ,  NRMSE: 0.078
# Step:280 ,  NRMSE: 0.080
# Step:281 ,  NRMSE: 0.078
# Step:282 ,  NRMSE: 0.080
# Step:283 ,  NRMSE: 0.078
# Step:284 ,  NRMSE: 0.080
# Step:285 ,  NRMSE: 0.077
# Step:286 ,  NRMSE: 0.080
# Step:287 ,  NRMSE: 0.077
# Step:288 ,  NRMSE: 0.080
# Step:289 ,  NRMSE: 0.077
# Step:290 ,  NRMSE: 0.080
# Step:291 ,  NRMSE: 0.077
# Step:292 ,  NRMSE: 0.080
# Step:293 ,  NRMSE: 0.077
# Step:294 ,  NRMSE: 0.080
# Step:295 ,  NRMSE: 0.077
# Step:296 ,  NRMSE: 0.080
# Step:297 ,  NRMSE: 0.077
# Step:298 ,  NRMSE: 0.080
# Step:299 ,  NRMSE: 0.077

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,3,1)
plt.title('GT')
plt.imshow(np.flipud(abs(norm_gt_img[0,0]).cpu()),cmap = 'gray')
plt.axis('off')
plt.subplot(2,3,2)
plt.title('Subsampled Image')
plt.imshow(np.flipud(abs(us_recon[0,0]).cpu()),cmap = 'gray')
plt.axis('off')
plt.subplot(2,3,3)
plt.title('Diffusion Recon')
plt.imshow(np.flipud(abs(cplx_recon[0,0]).cpu()),cmap = 'gray')
plt.axis('off')

plt.subplot(2,3,5)
plt.imshow(np.flipud(abs(gt_img[0,0]-us_recon[0,0]).cpu()),cmap = 'gray')
plt.axis('off')
plt.subplot(2,3,6)
plt.imshow(np.flipud(abs(gt_img[0,0]-cplx_recon[0,0]).cpu()),cmap = 'gray')
plt.axis('off')

plt.tight_layout(pad=0.0)
